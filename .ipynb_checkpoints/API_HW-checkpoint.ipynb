# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 645

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#weather api +url
url ="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# %%
# empty lists for data 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
        printing_city = response["name"]
        print(f"Processing Record {record} | {printing_city}")
        
        # Increase counter by one 
        record= record + 1
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Coos Bay
# Processing Record 2 | Longyearbyen
# Processing Record 3 | Kapaa
# Processing Record 4 | Mataura
# Processing Record 5 | Hermanus
# City not found. Skipping...
# Processing Record 6 | Jamestown
# Processing Record 7 | Ushuaia
# Processing Record 8 | Honiara
# Processing Record 9 | Vaitape
# Processing Record 10 | Puerto Ayora
# Processing Record 11 | Kigoma
# Processing Record 12 | Gat
# Processing Record 13 | Clyde River
# City not found. Skipping...
# Processing Record 14 | Bredasdorp
# City not found. Skipping...
# Processing Record 15 | Cape Town
# Processing Record 16 | Jalu
# City not found. Skipping...
# Processing Record 17 | Hithadhoo
# Processing Record 18 | Roald
# Processing Record 19 | Severo-Kurilsk
# Processing Record 20 | Barrow
# Processing Record 21 | Vaini
# Processing Record 22 | Yerbogachen
# Processing Record 23 | Ardakan
# Processing Record 24 | Brae
# Processing Record 25 | Nanortalik
# Processing Record 26 | Makakilo City
# Processing Record 27 | Albany
# Processing Record 28 | Punta Arenas
# Processing Record 29 | Tazovskiy
# Processing Record 30 | Poum
# Processing Record 31 | Senador Jose Porfirio
# Processing Record 32 | Tiksi
# Processing Record 33 | Busselton
# Processing Record 34 | Saint-Philippe
# Processing Record 35 | Butaritari
# Processing Record 36 | Tuktoyaktuk
# Processing Record 37 | Arraial do Cabo
# Processing Record 38 | East London
# Processing Record 39 | Saskylakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 40 | Port Hardy
# Processing Record 41 | Guayaramerin
# Processing Record 42 | Hilo
# Processing Record 43 | Atar
# Processing Record 44 | Constantine
# Processing Record 45 | Nikolskoye
# Processing Record 46 | Williston
# Processing Record 47 | Atuona
# Processing Record 48 | Port Hedland
# Processing Record 49 | College
# Processing Record 50 | Wattegama
# Processing Record 51 | Saldanha
# Processing Record 52 | General Pico
# Processing Record 53 | Westerland
# Processing Record 54 | Duba-Yurt
# Processing Record 55 | Dunedin
# Processing Record 56 | Krasnovishersk
# Processing Record 57 | Eureka
# Processing Record 58 | Cumana
# Processing Record 59 | Bathsheba
# Processing Record 60 | Nishihara
# Processing Record 61 | Cooma
# Processing Record 62 | Guerrero Negro
# Processing Record 63 | Igdir
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 64 | Karlstad
# Processing Record 65 | Salinas
# Processing Record 66 | Castro
# Processing Record 67 | Banikoara
# Processing Record 68 | Chokurdakh
# Processing Record 69 | Lesnoy
# Processing Record 70 | Acapulco
# Processing Record 71 | Rio Grande
# Processing Record 72 | Chuy
# Processing Record 73 | Necochea
# Processing Record 74 | Riyadh
# Processing Record 75 | Bethel
# Processing Record 76 | Mnogovershinnyy
# Processing Record 77 | Cidreira
# Processing Record 78 | Alghero
# Processing Record 79 | Moerai
# Processing Record 80 | Leningradskiy
# Processing Record 81 | Kavaratti
# Processing Record 82 | Litovko
# Processing Record 83 | Natal
# Processing Record 84 | Acajutla
# Processing Record 85 | Port Alfred
# Processing Record 86 | Rikitea
# City not found. Skipping...
# Processing Record 87 | Butembo
# Processing Record 88 | Victoria
# Processing Record 89 | Fengcheng
# Processing Record 90 | Qaanaaq
# Processing Record 91 | Hobart
# Processing Record 92 | Nioro
# City not found. Skipping...
# Processing Record 93 | Bluff
# City not found. Skipping...
# Processing Record 94 | Ancud
# Processing Record 95 | Sicamous
# Processing Record 96 | Suntar
# Processing Record 97 | Faanui
# Processing Record 98 | Kavieng
# City not found. Skipping...
# Processing Record 99 | Gambela
# Processing Record 100 | Georgetown
# Processing Record 101 | Fecamp
# Processing Record 102 | Bima
# Processing Record 103 | Erzin
# Processing Record 104 | Esperance
# Processing Record 105 | Taoudenni
# Processing Record 106 | Panama City
# Processing Record 107 | Thompson
# Processing Record 108 | Havre-Saint-Pierre
# City not found. Skipping...
# Processing Record 109 | Oussouye
# Processing Record 110 | Caceres
# Processing Record 111 | Dikson
# Processing Record 112 | Ulaangom
# Processing Record 113 | Talnakh
# Processing Record 114 | Outjo
# Processing Record 115 | Gombe
# Processing Record 116 | Abu Samrah
# Processing Record 117 | Upernavik
# Processing Record 118 | Coahuayana
# Processing Record 119 | Dawei
# Processing Record 120 | Grand-Santi
# Processing Record 121 | Banda Aceh
# Processing Record 122 | Porbandar
# Processing Record 123 | Airai
# Processing Record 124 | Boa Vista
# Processing Record 125 | Bandarbeyla
# Processing Record 126 | Sao Filipe
# Processing Record 127 | Coronado
# Processing Record 128 | Klaksvik
# Processing Record 129 | Kyzyl-Suu
# Processing Record 130 | Anzio
# Processing Record 131 | Namibe
# Processing Record 132 | Vestmannaeyjar
# Processing Record 133 | Bambous Virieux
# Processing Record 134 | Mar del Plata
# Processing Record 135 | Iqaluit
# Processing Record 136 | Constitucion
# Processing Record 137 | New Norfolk
# Processing Record 138 | Srednekolymsk
# Processing Record 139 | Lyudinovo
# Processing Record 140 | Lahaina
# Processing Record 141 | Lebu
# Processing Record 142 | Tsumeb
# Processing Record 143 | Lazaro Cardenas
# Processing Record 144 | Madimba
# Processing Record 145 | Alice Springs
# Processing Record 146 | Concepcion del Oro
# Processing Record 147 | Meulaboh
# Processing Record 148 | Dingle
# City not found. Skipping...
# Processing Record 149 | Saint George
# Processing Record 150 | Joshimath
# Processing Record 151 | Oskemen
# City not found. Skipping...
# Processing Record 152 | Kysyl-Syr
# Processing Record 153 | Dargaville
# Processing Record 154 | Galle
# Processing Record 155 | Mataram
# Processing Record 156 | Palana
# Processing Record 157 | Alofi
# Processing Record 158 | Viransehir
# City not found. Skipping...
# Processing Record 159 | Norman Wells
# Processing Record 160 | Omboue
# Processing Record 161 | Mae Hong Son
# Processing Record 162 | Adre
# Processing Record 163 | Mujiayingzi
# City not found. Skipping...
# Processing Record 164 | Chara
# Processing Record 165 | Hobyo
# Processing Record 166 | Khatanga
# Processing Record 167 | Tasiilaq
# Processing Record 168 | Bose
# Processing Record 169 | Chenzhou
# Processing Record 170 | Laguna
# Processing Record 171 | Provideniya
# Processing Record 172 | Conceicao do Araguaia
# Processing Record 173 | Vanimo
# Processing Record 174 | San Patricio
# City not found. Skipping...
# Processing Record 175 | Intipuca
# Processing Record 176 | Isangel
# Processing Record 177 | Pevek
# Processing Record 178 | Eenhana
# Processing Record 179 | Dire Dawa
# Processing Record 180 | Yellowknife
# Processing Record 181 | Iskateley
# Processing Record 182 | Batagay-Alyta
# Processing Record 183 | Mahebourg
# Processing Record 184 | Paamiut
# Processing Record 185 | Narsaq
# Processing Record 186 | Mercedes
# Processing Record 187 | Lubumbashi
# City not found. Skipping...
# Processing Record 188 | Orlik
# Processing Record 189 | Bilma
# Processing Record 190 | Vila do Maio
# Processing Record 191 | Port Elizabeth
# Processing Record 192 | Amalapuram
# Processing Record 193 | Saint-Pierre
# Processing Record 194 | Selenduma
# City not found. Skipping...
# Processing Record 195 | Aguimes
# Processing Record 196 | Torbay
# Processing Record 197 | Selma
# Processing Record 198 | Sapulpa
# City not found. Skipping...
# Processing Record 199 | Cherskiy
# Processing Record 200 | Muros
# Processing Record 201 | Matadi
# Processing Record 202 | Westport
# City not found. Skipping...
# Processing Record 203 | Lloydminster
# Processing Record 204 | Avarua
# Processing Record 205 | Kaitangata
# Processing Record 206 | Chapais
# Processing Record 207 | Sioux Lookout
# Processing Record 208 | Otane
# City not found. Skipping...
# Processing Record 209 | Gornyatskiy
# Processing Record 210 | Semey
# Processing Record 211 | Ariogala
# Processing Record 212 | Qaqortoq
# Processing Record 213 | Baykalsk
# Processing Record 214 | Lipari
# Processing Record 215 | Belaya Gora
# Processing Record 216 | Davila
# Processing Record 217 | Rengasdengklok
# Processing Record 218 | Geraldton
# Processing Record 219 | Sao Miguel do Araguaia
# Processing Record 220 | Tuatapere
# Processing Record 221 | Kirakira
# Processing Record 222 | Northam
# Processing Record 223 | Balkanabat
# Processing Record 224 | Bonnyville
# Processing Record 225 | Katsuura
# Processing Record 226 | Montepuez
# Processing Record 227 | Sonoita
# Processing Record 228 | Shakhtinsk
# Processing Record 229 | Teguldet
# Processing Record 230 | Ilulissat
# Processing Record 231 | Nalut
# Processing Record 232 | Matagami
# Processing Record 233 | Padang
# City not found. Skipping...
# Processing Record 234 | Babstovo
# Processing Record 235 | Sola
# Processing Record 236 | Zhigansk
# Processing Record 237 | Saint Anthony
# Processing Record 238 | Mecca
# Processing Record 239 | Morehead
# Processing Record 240 | Pacific Grove
# Processing Record 241 | Leshukonskoye
# Processing Record 242 | Kahului
# Processing Record 243 | Chernyshevskiy
# City not found. Skipping...
# Processing Record 244 | Port Blair
# Processing Record 245 | Alihe
# Processing Record 246 | Redmond
# Processing Record 247 | Biggar
# Processing Record 248 | Tecoanapa
# Processing Record 249 | Cabra
# Processing Record 250 | Cockburn Town
# Processing Record 251 | Mansa
# Processing Record 252 | Marzuq
# City not found. Skipping...
# Processing Record 253 | Ribeira Grande
# Processing Record 254 | Kalanchak
# Processing Record 255 | Mwinilunga
# Processing Record 256 | Esmeraldas
# Processing Record 257 | Mackenzie
# Processing Record 258 | Wuning
# Processing Record 259 | Wembley
# Processing Record 260 | Burnie
# City not found. Skipping...
# Processing Record 261 | Secunda
# Processing Record 262 | Salalah
# City not found. Skipping...
# Processing Record 263 | Vardo
# City not found. Skipping...
# Processing Record 264 | Benguela
# Processing Record 265 | Mehendiganj
# Processing Record 266 | Yulara
# Processing Record 267 | Takoradi
# Processing Record 268 | Santa Rosa
# Processing Record 269 | Palmer
# Processing Record 270 | Iquitos
# Processing Record 271 | Tura
# Processing Record 272 | Aloleng
# Processing Record 273 | Luderitz
# Processing Record 274 | Ngunguru
# Processing Record 275 | Mbini
# City not found. Skipping...
# Processing Record 276 | Dori
# Processing Record 277 | Itacare
# Processing Record 278 | Lensk
# Processing Record 279 | Tomigusuku
# Processing Record 280 | Parabel
# Processing Record 281 | Toora-Khem
# Processing Record 282 | Tautira
# Processing Record 283 | Kodiak
# City not found. Skipping...
# Processing Record 284 | Entre Rios
# Processing Record 285 | Mangai
# Processing Record 286 | Umm Kaddadah
# Processing Record 287 | Shaowu
# Processing Record 288 | Husavik
# Processing Record 289 | Olinda
# Processing Record 290 | Baiquan
# City not found. Skipping...
# Processing Record 291 | Broken Hill
# City not found. Skipping...
# Processing Record 292 | Kloulklubed
# Processing Record 293 | Biak
# Processing Record 294 | Gizo
# Processing Record 295 | San Vicente de Chucuri
# Processing Record 296 | Karratha
# Processing Record 297 | Atbasar
# Processing Record 298 | Daru
# Processing Record 299 | Malanje
# Processing Record 300 | Togur
# Processing Record 301 | Cabo San Lucas
# Processing Record 302 | Kiria
# City not found. Skipping...
# Processing Record 303 | Sao Joao da Barra
# Processing Record 304 | Hualmay
# Processing Record 305 | Rosarito
# Processing Record 306 | Biala Podlaska
# Processing Record 307 | Elizabeth City
# Processing Record 308 | Sitka
# Processing Record 309 | Xai-Xai
# Processing Record 310 | Shenjiamen
# Processing Record 311 | Abeche
# Processing Record 312 | Hamilton
# Processing Record 313 | Manokwari
# Processing Record 314 | Lota
# Processing Record 315 | Grand Gaube
# Processing Record 316 | Perth
# Processing Record 317 | Rudnogorsk
# Processing Record 318 | Ondjiva
# Processing Record 319 | Mayo
# Processing Record 320 | Kruisfontein
# Processing Record 321 | El Espinal
# Processing Record 322 | Cururupu
# Processing Record 323 | Nisko
# Processing Record 324 | Kiunga
# Processing Record 325 | Vitre
# Processing Record 326 | Mareeba
# Processing Record 327 | Avera
# Processing Record 328 | Capinzal
# Processing Record 329 | Kishi
# Processing Record 330 | Umm Lajj
# Processing Record 331 | Yhu
# Processing Record 332 | Ontario
# Processing Record 333 | Bubaque
# Processing Record 334 | Talcahuano
# Processing Record 335 | Grindavik
# Processing Record 336 | Pinsk
# City not found. Skipping...
# Processing Record 337 | Juruti
# Processing Record 338 | El Carmen
# City not found. Skipping...
# Processing Record 339 | Ipojuca
# Processing Record 340 | Souillac
# Processing Record 341 | Broome
# Processing Record 342 | Lavrentiya
# Processing Record 343 | Fortuna
# Processing Record 344 | Newport
# City not found. Skipping...
# Processing Record 345 | Chimore
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 346 | Fairbanks
# Processing Record 347 | Barcelos
# Processing Record 348 | Vila Franca do Campo
# Processing Record 349 | Oakley
# Processing Record 350 | Vao
# Processing Record 351 | Bay Roberts
# Processing Record 352 | Biltine
# Processing Record 353 | Zabol
# City not found. Skipping...
# Processing Record 354 | Mehamn
# Processing Record 355 | Koyelga
# City not found. Skipping...
# Processing Record 356 | Lagoa
# Processing Record 357 | Stanghelle
# Processing Record 358 | Turukhansk
# Processing Record 359 | Scottsbluff
# Processing Record 360 | Pangnirtung
# Processing Record 361 | Yabucoa
# Processing Record 362 | Jasper
# Processing Record 363 | Ostrovnoy
# Processing Record 364 | Yatou
# Processing Record 365 | Beloha
# Processing Record 366 | LOS ALGARROBOS
# Processing Record 367 | Mao
# Processing Record 368 | Kieta
# Processing Record 369 | Betong
# Processing Record 370 | Naryan-Mar
# Processing Record 371 | Conde
# Processing Record 372 | Visby
# Processing Record 373 | Mawlaik
# Processing Record 374 | Tsabong
# Processing Record 375 | Elban
# Processing Record 376 | Harper
# Processing Record 377 | Kudahuvadhoo
# Processing Record 378 | Carnarvon
# Processing Record 379 | Mandali
# Processing Record 380 | Port Augusta
# Processing Record 381 | Richards Bay
# Processing Record 382 | Kajaani
# Processing Record 383 | Bud
# Processing Record 384 | Jinxiang
# Processing Record 385 | Ilheus
# Processing Record 386 | Shirokiy
# City not found. Skipping...
# Processing Record 387 | Pisco
# Processing Record 388 | Tomatlan
# Processing Record 389 | Craig
# Processing Record 390 | Sawakin
# City not found. Skipping...
# Processing Record 391 | Inverell
# Processing Record 392 | Fatehpur
# Processing Record 393 | Taksimo
# City not found. Skipping...
# Processing Record 394 | Ketchikan
# Processing Record 395 | San Carlos de Bariloche
# Processing Record 396 | Tineo
# Processing Record 397 | Rawson
# Processing Record 398 | Angoche
# Processing Record 399 | Flinders
# Processing Record 400 | Monki
# Processing Record 401 | Porto Murtinho
# Processing Record 402 | Naruja
# Processing Record 403 | Amapa
# Processing Record 404 | Piazza Armerina
# Processing Record 405 | Athabasca
# Processing Record 406 | Jam Sahib
# Processing Record 407 | Ulagan
# Processing Record 408 | Whitehorse
# Processing Record 409 | Itupiranga
# Processing Record 410 | Prince Rupert
# Processing Record 411 | High Level
# Processing Record 412 | Parker
# Processing Record 413 | Romuli
# Processing Record 414 | Sabang
# Processing Record 415 | Nelson Bay
# Processing Record 416 | Marovoay
# Processing Record 417 | Althofen
# Processing Record 418 | Ust-Uda
# Processing Record 419 | Inirida
# Processing Record 420 | Coquimbo
# Processing Record 421 | Leh
# Processing Record 422 | Boguchany
# Processing Record 423 | Aguada de Pasajeros
# Processing Record 424 | Aklera
# Processing Record 425 | Casper
# City not found. Skipping...
# Processing Record 426 | Meadow Lake
# Processing Record 427 | San Cristobal
# Processing Record 428 | Lompoc
# Processing Record 429 | Twin Falls
# Processing Record 430 | Bambanglipuro
# Processing Record 431 | Gediz
# City not found. Skipping...
# Processing Record 432 | Hays
# Processing Record 433 | Urgut
# Processing Record 434 | Hambantota
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 435 | Lagos
# Processing Record 436 | Kendari
# City not found. Skipping...
# Processing Record 437 | Port Hawkesbury
# City not found. Skipping...
# Processing Record 438 | Caravelas
# Processing Record 439 | Tofield
# Processing Record 440 | Loiza
# Processing Record 441 | Pampas
# Processing Record 442 | Ahipara
# Processing Record 443 | Jijiang
# Processing Record 444 | Senneterre
# Processing Record 445 | Jardim
# Processing Record 446 | Te Anau
# City not found. Skipping...
# Processing Record 447 | Susehri
# Processing Record 448 | Pontianak
# Processing Record 449 | Camopi
# Processing Record 450 | Uarini
# Processing Record 451 | Chicama
# City not found. Skipping...
# Processing Record 452 | Mogadishu
# Processing Record 453 | Gafanha da Encarnacao
# Processing Record 454 | Luangwa
# Processing Record 455 | Llanes
# Processing Record 456 | Egvekinot
# City not found. Skipping...
# Processing Record 457 | Gopalpur
# City not found. Skipping...
# Processing Record 458 | Nouadhibou
# Processing Record 459 | Andros Town
# Processing Record 460 | Sunrise
# Processing Record 461 | The Valley
# Processing Record 462 | Gazli
# Processing Record 463 | Solnechnyy
# Processing Record 464 | Monte Aprazivel
# Processing Record 465 | Shimoda
# Processing Record 466 | Ashtian
# Processing Record 467 | Severo-Yeniseyskiy
# Processing Record 468 | Mapiri
# Processing Record 469 | Mandalgovi
# Processing Record 470 | Davenda
# Processing Record 471 | Mount Isa
# Processing Record 472 | Kokoda
# City not found. Skipping...
# Processing Record 473 | Dicabisagan
# Processing Record 474 | Los Llanos de Aridane
# Processing Record 475 | Itaituba
# Processing Record 476 | Monopoli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 477 | Rio Gallegos
# Processing Record 478 | Nhulunbuy
# Processing Record 479 | Fare
# City not found. Skipping...
# Processing Record 480 | Mokhsogollokh
# Processing Record 481 | Pavilosta
# Processing Record 482 | Palmerston
# Processing Record 483 | Norfolk
# Processing Record 484 | Fukue
# Processing Record 485 | Tigil
# Processing Record 486 | Port Lincoln
# Processing Record 487 | Mezen
# Processing Record 488 | Gandajika
# Processing Record 489 | Slubice
# Processing Record 490 | La Romana
# Processing Record 491 | Mama
# City not found. Skipping...
# Processing Record 492 | Ronne
# Processing Record 493 | Yelovo
# Processing Record 494 | Gualeguay
# Processing Record 495 | Hoa Binh
# Processing Record 496 | Deputatskiy
# Processing Record 497 | Zaqatala
# Processing Record 498 | Shingu
# Processing Record 499 | Goderich
# Processing Record 500 | Opotiki
# Processing Record 501 | Muriwai Beach
# Processing Record 502 | Nuuk
# Processing Record 503 | Abu Dhabi
# City not found. Skipping...
# Processing Record 504 | Aquiraz
# Processing Record 505 | Lososina
# Processing Record 506 | Upata
# Processing Record 507 | Ponta do Sol
# City not found. Skipping...
# Processing Record 508 | Pobe
# Processing Record 509 | Parthenay
# City not found. Skipping...
# Processing Record 510 | Acari
# Processing Record 511 | Clermont
# Processing Record 512 | Nabire
# Processing Record 513 | Naze
# Processing Record 514 | Artyom
# Processing Record 515 | Bilibino
# Processing Record 516 | Tiznit
# Processing Record 517 | Aranos
# Processing Record 518 | Dabat
# Processing Record 519 | Aviles
# Processing Record 520 | Poyarkovo
# Processing Record 521 | Waipawa
# Processing Record 522 | Katangli
# Processing Record 523 | Wajima
# Processing Record 524 | Tevaitoa
# Processing Record 525 | Bealanana
# Processing Record 526 | Sinnamary
# Processing Record 527 | Lovozero
# Processing Record 528 | Saint-Augustin
# Processing Record 529 | Carutapera
# City not found. Skipping...
# Processing Record 530 | Rosetta
# Processing Record 531 | Nemuro
# City not found. Skipping...
# Processing Record 532 | Dalvik
# Processing Record 533 | Waddan
# Processing Record 534 | Ereymentau
# Processing Record 535 | Sarlat-la-Caneda
# Processing Record 536 | San Matias
# City not found. Skipping...
# Processing Record 537 | Ararat
# Processing Record 538 | Lishu
# Processing Record 539 | Arlit
# Processing Record 540 | Pandan
# City not found. Skipping...
# Processing Record 541 | Vila Velha
# Processing Record 542 | Virginia Beach
# Processing Record 543 | Alyangula
# Processing Record 544 | Jacareacanga
# Processing Record 545 | Hakkari
# City not found. Skipping...
# Processing Record 546 | San Ramon
# Processing Record 547 | Ziro
# Processing Record 548 | Touros
# Processing Record 549 | Fortuna Foothills
# Processing Record 550 | Lima
# City not found. Skipping...
# Processing Record 551 | Canico
# Processing Record 552 | Fort-Shevchenko
# Processing Record 553 | El Dorado
# Processing Record 554 | Rabaul
# Processing Record 555 | Kalmar
# Processing Record 556 | Cienfuegos
# Processing Record 557 | Itarema
# Processing Record 558 | Danville
# Processing Record 559 | Havoysund
# Processing Record 560 | Vuktyl
# Processing Record 561 | Petropavlovka
# Processing Record 562 | Kita
# Processing Record 563 | Ugoofaaru
# Processing Record 564 | Vadso
# Processing Record 565 | Santona
# Processing Record 566 | Svobodnyy
# Processing Record 567 | Maniitsoq
# Processing Record 568 | Podor
# Processing Record 569 | Grants Pass
# Processing Record 570 | Byron Bay
# Processing Record 571 | Weston
# Processing Record 572 | Bemidji
# City not found. Skipping...
# Processing Record 573 | Sarandi
# City not found. Skipping...
# Processing Record 574 | Lusambo
# Processing Record 575 | Iquique

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated

weather_dict = {
    "City": city,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
#       City  Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# 0  iquique          90      US  1562705296        87  43.37 -124.22     70.00
# 1  iquique           0      NO  1562705296        81  78.22   15.63     48.20
# 2  iquique          40      US  1562705296        74  22.08 -159.32     84.20
# 3  iquique         100      NZ  1562705296        97 -46.19  168.86     39.00
# 4  iquique           0      ZA  1562705297        97 -34.42   19.24     55.99
#
#    Wind Speed
# 0       10.29
# 1       10.29
# 2       12.75
# 3        2.93
# 4       14.83

# %%
# Display count of weather data values 
weather_data.count()
# Out:
# City          575
# Cloudiness    575
# Country       575
# Date          575
# Humidity      575
# Lat           575
# Lng           575
# Max Temp      575
# Wind Speed    575
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()
